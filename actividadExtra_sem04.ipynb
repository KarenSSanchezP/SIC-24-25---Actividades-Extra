# %% [markdown]
# ## Actividad Extra - Semana 4
# ##### (Puntos extra sobre quizz y actividad asíncrona)
# *Hecho por: Karen Stefany Sánchez Pocasangre*
#
# Recuerden la actividad (opcional puntos extra sobre las actividades de esta semana):
#
# * Desarrollar las funciones de la estructura Deque.
#
# ![image.png](attachment:image.png)

# %%
class Deque:
    def __init__(self):
        self.deque = []
    def add_first(self, item):
        self.deque.insert(0, item)
    def remove_first(self):
        return None if len(self.deque) == 0 else self.deque.pop(0)
    def add_last(self, item):
        self.deque.append(item)
    def remove_last(self):
        return None if len(self.deque) == 0 else self.deque.pop()
    def __str__(self):
        return f"Valores: {self.deque}"

# Haciendo pruebas
p1 = Deque()

p1.add_first(8)
print(p1)
p1.add_first("h")
print(p1)
p1.add_first(15)
print(p1)
p1.add_last("a")
print(p1)
p1.add_last("c")
print(p1)
p1.remove_first()
print(p1)
p1.remove_last()
print(p1)
# Out:
# Valores: [8]
# Valores: ['h', 8]
# Valores: [15, 'h', 8]
# Valores: [15, 'h', 8, 'a']
# Valores: [15, 'h', 8, 'a', 'c']
# Valores: ['h', 8, 'a', 'c']
# Valores: ['h', 8, 'a']
